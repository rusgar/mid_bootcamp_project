# %%
import pandas as pd
import numpy as np
df = pd.read_csv("../data/confirmed_global.csv")

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  4/1/21  4/2/21  4/3/21  4/4/21  \
# 0        0        0        0        0  ...   56517   56572   56595   56676
# 1        0        0        0        0  ...  125506  125842  126183  126531
# 2        0        0        0        0  ...  117304  117429  117524  117622
# 3        0        0        0        0  ...   12053   12115   12174   12231
# 4        0        0        0        0  ...   22399   22467   22579   22631
#
#    4/5/21  4/6/21  4/7/21  4/8/21  4/9/21  4/10/21
# ...

# %%
df.shape
# Out:
# (274, 449)

# %%
df.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '4/1/21', '4/2/21', '4/3/21', '4/4/21', '4/5/21', '4/6/21', '4/7/21',
#        '4/8/21', '4/9/21', '4/10/21'],
#       dtype='object', length=449)

# %%
duplicados = df.duplicated().sum()
print(f" En este datafrane hay duplicados: {duplicados}")
df_2=df.drop_duplicates()
df_2.head()
# Out:
#  En este datafrane hay duplicados: 0
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  4/1/21  4/2/21  4/3/21  4/4/21  \
# 0        0        0        0        0  ...   56517   56572   56595   56676
# 1        0        0        0        0  ...  125506  125842  126183  126531
# 2        0        0        0        0  ...  117304  117429  117524  117622
# 3        0        0        0        0  ...   12053   12115   12174   12231
# 4        0        0        0        0  ...   22399   22467   22579   22631
#
# ...

# %%
df_3 = df_2.drop(df.columns[0], axis='columns')
df_3.head()
# Out:
#   Country/Region       Lat       Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0    Afghanistan  33.93911  67.709953        0        0        0        0
# 1        Albania  41.15330  20.168300        0        0        0        0
# 2        Algeria  28.03390   1.659600        0        0        0        0
# 3        Andorra  42.50630   1.521800        0        0        0        0
# 4         Angola -11.20270  17.873900        0        0        0        0
#
#    1/26/20  1/27/20  1/28/20  ...  4/1/21  4/2/21  4/3/21  4/4/21  4/5/21  \
# 0        0        0        0  ...   56517   56572   56595   56676   56717
# 1        0        0        0  ...  125506  125842  126183  126531  126795
# 2        0        0        0  ...  117304  117429  117524  117622  117739
# 3        0        0        0  ...   12053   12115   12174   12231   12286
# 4        0        0        0  ...   22399   22467   22579   22631   22717
#
#    4/6/21  4/7/21  4/8/21  4/9/21  4/10/21
# ...

# %%
numericos = df.select_dtypes(include=[np.number]).columns.values

print (f" Las columnas numéricas son: {'/ '.join(numericos)} ")
# Out:
#  Las columnas numéricas son: Lat/ Long/ 1/22/20/ 1/23/20/ 1/24/20/ 1/25/20/ 1/26/20/ 1/27/20/ 1/28/20/ 1/29/20/ 1/30/20/ 1/31/20/ 2/1/20/ 2/2/20/ 2/3/20/ 2/4/20/ 2/5/20/ 2/6/20/ 2/7/20/ 2/8/20/ 2/9/20/ 2/10/20/ 2/11/20/ 2/12/20/ 2/13/20/ 2/14/20/ 2/15/20/ 2/16/20/ 2/17/20/ 2/18/20/ 2/19/20/ 2/20/20/ 2/21/20/ 2/22/20/ 2/23/20/ 2/24/20/ 2/25/20/ 2/26/20/ 2/27/20/ 2/28/20/ 2/29/20/ 3/1/20/ 3/2/20/ 3/3/20/ 3/4/20/ 3/5/20/ 3/6/20/ 3/7/20/ 3/8/20/ 3/9/20/ 3/10/20/ 3/11/20/ 3/12/20/ 3/13/20/ 3/14/20/ 3/15/20/ 3/16/20/ 3/17/20/ 3/18/20/ 3/19/20/ 3/20/20/ 3/21/20/ 3/22/20/ 3/23/20/ 3/24/20/ 3/25/20/ 3/26/20/ 3/27/20/ 3/28/20/ 3/29/20/ 3/30/20/ 3/31/20/ 4/1/20/ 4/2/20/ 4/3/20/ 4/4/20/ 4/5/20/ 4/6/20/ 4/7/20/ 4/8/20/ 4/9/20/ 4/10/20/ 4/11/20/ 4/12/20/ 4/13/20/ 4/14/20/ 4/15/20/ 4/16/20/ 4/17/20/ 4/18/20/ 4/19/20/ 4/20/20/ 4/21/20/ 4/22/20/ 4/23/20/ 4/24/20/ 4/25/20/ 4/26/20/ 4/27/20/ 4/28/20/ 4/29/20/ 4/30/20/ 5/1/20/ 5/2/20/ 5/3/20/ 5/4/20/ 5/5/20/ 5/6/20/ 5/7/20/ 5/8/20/ 5/9/20/ 5/10/20/ 5/11
# ...

# %%
categoricas = df.select_dtypes(include=object).columns.values
categoricas
# Out:
# array(['Province/State', 'Country/Region'], dtype=object)

# %%
df[categoricas].describe()
# Out:
#                    Province/State Country/Region
# count                          85            274
# unique                         85            192
# top     Saint Pierre and Miquelon          China
# freq                            1             33
